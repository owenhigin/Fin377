# %% [markdown]
# <a href="https://colab.research.google.com/github/owenhigin/Fin377/blob/main/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 3
#
# ## Submitting the assignment
#
# 1. When you are done, rename this Colab file to HW3 <username>,.ipynb eg "HW3 deb219.ipynb".
# 1. Then _**share**_ this work file with me (deb219@lehigh.edu) by clicking the big Share button in the upper right of this page.
# 1. And upload it to coursesite under HW3 for record keeping (File > Download > ipynb).
#
# **I'll subtract points for not doing any these things.**
#
# ## Pre-requisites (or things you will learn here):
#
# - Working My GPT Hedge Fund Code and familiarity with the project
# - Data sources for finance lecture
#
# ## Learning goals:
#
# - Think critically about trading and show it
# - Increase familiarity with different data sources available to you
#
# ## Time expectations
#
# **Stop working after 60 minutes and ask me and your classmates about it in the Groupme chat.**
#
# This assignment overlaps a lot with the project and in-class discussions. It will give you an opportunity to think deeper about what we are covering.

# %% [markdown]
# ## Exercises related to the LLM stock picker project (aka My GPT Hedge Fund)
#
# For Q1-Q4, open my [LLM stock picker/Data/2025-09-09/weight_prompt.txt](https://drive.google.com/file/d/1eyIgqF4jeOs46HNyJG1SHdMugP_yE3hy/view?usp=drive_link) by clicking the options button and “open with” “text editor”.

# %% [markdown]
# ### Q1. Thinking critically, do we like the macro report? How might we improve it?
#
# Answer here.
#
# ### Q2. After reading the stock investment reports in that file: Are the "investment reports" justified by the available facts?
#
# Answer here.
#
# ### Q3. List any errors you find in the reports, along with your justification for dispute. Winner gets a starbucks card.
#
# Answer here.
#
# ### Q4. What other information would you like it to consider when weighting firms? How might we get that information? How and where would you integrate that info within the process?
#
# Answer here.
#
# ### Q5. Open [recommendation_reasoning.txt](https://drive.google.com/file/d/17UAuvmoXrJzdwsjR_qWwGt3p5372pC2C/view?usp=drive_link) with the text editor.
#
#
# List 2-3 things you like about it:
#
# -
# -
# -
#
# List 2-3 things you dislike about it.
#
# -
# -
# -

# %% [markdown]
# ## Exercises related to data sources
#
# ### Q6. Learning more about some groundbreaking studies with this data.
#
# - [In class, I asked GPT to explain some important studies using combinations of the data above](https://chatgpt.com/share/68c9a42a-fa78-8009-8d3e-59d2f804524d), and it spent 5 minutes thinking about it.
# - Additionally, there is amazing work harnessing the power of SEC filings, like
#     - [Check this claim: Identifying changes in 10-K/Q filings can generate a   % alpha](https://papers.ssrn.com/sol3/papers.cfm?abstract_id=1658471)
#     - [Prof. Hanley measured emerging risks in the financial sector](https://papers.ssrn.com/sol3/papers.cfm?abstract_id=2792943)
#     - [Build a unique list of competitors for each firm (really powerful!)](https://papers.ssrn.com/sol3/papers.cfm?abstract_id=1520062)
#     - [I used 10-K text to identify public rivals of startup firms](https://papers.ssrn.com/abstract=3245839)
#
# Go to my chat with GPT above, and ask it to explain more about the Mian and Sufi paper, and then come back here and summarize it in your own words.
#
# Put your answer below.
